# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("Temporary_data3_-_Copy.xlsx")
data.head()
# Out:
#    SEX  EDUC  MARISTAT  INDEPEND  RESIDENC  NACCFAM  ANYMEDS  SMOKYRS  \
# 0    2    18         1         1         1        1        1        0
# 1    1    11         1         1         1        1        1        0
# 2    2    16         1         1         1        1        1       10
# 3    1    14         1         1         1        0        1        0
# 4    1    16         1         1         2        0        1       50
#
#    NACCTBI  DIABETES  ...   RSUPFR  RSUPFRM  RSUPPAR  RSUPPARM  RSUPTEM  \
# 0        0         0  ...  27.9038   2.2157  10.3481    1.7014  13.4250
# 1        0         0  ...  29.0600   2.6900   9.2500    1.6300  14.8800
# 2        0         1  ...  33.0000   2.5400  13.6900    1.5600  16.2300
# 3        0         1  ...  31.6800   2.4100   9.6400    1.4500  15.1100
# 4        0         0  ...  28.0631   1.9501   9.1125    1.0427  13.3763
#
#    RSUPTEMM  RSUPMAR  RSUPMARM  RTRTEM  RTRTEMM
# 0    1.7419   9.8700    1.6792  0.8906   1.1947
# ...

# %% [markdown]
# TASK-4A: Please present a descriptive statistics analysis to provide a general understanding of the dataset. (describe)

# %%
data.describe()
# Out:
#                SEX         EDUC     MARISTAT     INDEPEND     RESIDENC  \
# count  1354.000000  1354.000000  1354.000000  1354.000000  1354.000000
# mean      1.573855    15.223781     1.658789     1.316100     1.112999
# std       0.494698     3.418699     1.136754     0.598538     0.360372
# min       1.000000     0.000000     1.000000     1.000000     1.000000
# 25%       1.000000    12.000000     1.000000     1.000000     1.000000
# 50%       2.000000    16.000000     1.000000     1.000000     1.000000
# 75%       2.000000    18.000000     2.000000     2.000000     1.000000
# max       2.000000    25.000000     6.000000     4.000000     4.000000
#
#            NACCFAM      ANYMEDS      SMOKYRS      NACCTBI     DIABETES  ...  \
# count  1354.000000  1354.000000  1354.000000  1354.000000  1354.000000  ...
# mean      0.631462     0.952733     9.754801     0.127031     0.192762  ...
# std       0.482586     0.212289    14.351222     0.333131     0.432160  ...
# ...

# %% [markdown]
# TASK-4B: Please provide the visual illustrations of the dataset that will demonstrate the insightful distributions with respect to the target column (CDRGLOB: the level of the Alzheimer Disease -AD)

# %%
x = data ["NACCMMSE"]
y = data["HIPPOVOL"]
labels = data["CDRGLOB"]
plt.scatter(x, y, s=20, cmap = "viridis", c=labels, alpha=0.5)
plt.xlabel("Total MMSE score (using D-L-R-O-W)")
plt.ylabel("Hippocampus Volume")
plt.title("MMSE Score - Hippocampus vol. Scatter")
plt.colorbar()
plt.show()

# %%
x = data ["SMOKYRS"]
y = data["ALCOHOL"]
labels = data["CDRGLOB"]
plt.scatter(y, x, s=20, cmap = "viridis", c=labels, alpha=0.5)
plt.ylabel("Smoke")
plt.xlabel("Alcohol")
plt.title("Smoke - Alcohol Scatter")
plt.colorbar()
plt.show()

# %%
y = data ["NACCAGEB"]
x = data["NACCBMI"]
labels = data["CDRGLOB"]
plt.scatter(x, y, s=20, cmap = "viridis", c=labels, alpha=0.5)
plt.xlabel("BMI")
plt.ylabel("Age")
plt.title("BMI - Age Scatter")
plt.colorbar()
plt.show()

# %% [markdown]
# TASK-4C: Please provide a correlation analysis between two different variables/features and argue for the analysis outputs.

# %%
a = data.corr()
a
# Out:
#                SEX      EDUC  MARISTAT  INDEPEND  RESIDENC   NACCFAM  \
# SEX       1.000000 -0.129742  0.244620 -0.098873  0.054726 -0.005097
# EDUC     -0.129742  1.000000 -0.021607 -0.108642 -0.030139  0.062121
# MARISTAT  0.244620 -0.021607  1.000000 -0.099897  0.101406 -0.034038
# INDEPEND -0.098873 -0.108642 -0.099897  1.000000  0.115258 -0.036503
# RESIDENC  0.054726 -0.030139  0.101406  0.115258  1.000000 -0.057857
# ...            ...       ...       ...       ...       ...       ...
# RSUPTEMM  0.057830  0.041457  0.083243 -0.359562  0.018632 -0.030018
# RSUPMAR  -0.231002  0.184778 -0.022053 -0.143379 -0.084733  0.087566
# RSUPMARM  0.040348  0.145529  0.019383 -0.189939  0.076612  0.074872
# RTRTEM   -0.148505  0.192072 -0.059230 -0.055922 -0.118758  0.114719
# RTRTEMM  -0.008018  0.193395 -0.044063 -0.042208 -0.117984  0.135564
#
#            ANYMEDS   SMOKYRS   NACCTBI  DIABETES  ...    RSUPFR   RSUPFRM  \
# ...

# %%
a = pd.DataFrame(data=a)
a = a.iloc[16,:] # CDRGLOB ile korelasyonları tek listede aldım
a
# Out:
# SEX        -0.180540
# EDUC       -0.140977
# MARISTAT   -0.141259
# INDEPEND    0.693881
# RESIDENC    0.047407
#               ...
# RSUPTEMM   -0.348159
# RSUPMAR    -0.164707
# RSUPMARM   -0.268851
# RTRTEM     -0.120294
# RTRTEMM    -0.172810
# Name: CDRGLOB, Length: 192, dtype: float64

# %%
b= list()
c = list()
for i in range(192): #liste uzunluğu 192
  if (a.iloc[i] > 0.40) or (a.iloc[i] < (-0.40)): #Önemli korelasyonları almak için kayda değer olan en küçük negatif ve pozitifleri görmek istiyorum
    b.append(a.iloc[i]) 
    c.append(i) #index no

  else:
    continue

print(b) #korelasyon değerleri
print(c) #index numaraları
# Out:
# [0.693881441068507, 1.0, 0.448557906906442, -0.7466604954702506, -0.4490687655921006, -0.44218473687743903, -0.42406795503177025, 0.4140328348985458, 0.40680634500294977, 0.42020393728247973, -0.45364582271109466, -0.47820726551581083]
# [3, 16, 23, 31, 44, 50, 51, 52, 53, 54, 75, 137]

# %%
a = a.iloc[c]
a #ilgili korelasyon değerlerine karşılık gelen kolon isimleri
# Out:
# INDEPEND    0.693881
# CDRGLOB     1.000000
# APA         0.448558
# NACCMMSE   -0.746660
# HIPPOVOL   -0.449069
# LHIPPO     -0.442185
# RHIPPO     -0.424068
# LLATVENT    0.414033
# RLATVENT    0.406806
# LATVENT     0.420204
# LENTM      -0.453646
# RENTM      -0.478207
# Name: CDRGLOB, dtype: float64

# %% [markdown]
# En yüksek negatif korelasyona sahip olan kolon NACCMMSE olup, INDEPEND kolonu da oldukça yüksek bir korelasyona sahiptir. Diğer çıkan kolonların da korelasyon oranları kayda değerdir.

# %% [markdown]
# TASK-4D: Please provide several pivot tables for insightful illustrations both via tables and figures.

# %%
naccmmse = pd.qcut(data["NACCMMSE"], 3)
data.pivot_table("GRAYVOL", index="CDRGLOB", columns=naccmmse, aggfunc="count")
# Out:
# NACCMMSE  (5.999, 26.0]  (26.0, 29.0]  (29.0, 30.0]
# CDRGLOB
# 0                    54           296           296
# 1                   225           219            52
# 2                   144            20             1
# 3                    47             0             0

# %%
data.pivot_table("GRAYVOL", index=["CDRGLOB","SEX"], columns=naccmmse, aggfunc="count")
# Out:
# NACCMMSE     (5.999, 26.0]  (26.0, 29.0]  (29.0, 30.0]
# CDRGLOB SEX
# 0       1               27            95            92
#         2               27           201           204
# 1       1              113           104            26
#         2              112           115            26
# 2       1               79            14             0
#         2               65             6             1
# 3       1               27             0             0
#         2               20             0             0

# %%
data.pivot_table("GRAYVOL", index=["CDRGLOB","SEX"], columns=naccmmse, aggfunc="count").plot(kind="bar")

# %%
data.pivot_table("GRAYVOL", index=["CDRGLOB","SEX"], columns=["INDEPEND", naccmmse])
# Out:
# INDEPEND                1                                       2  \
# NACCMMSE    (5.999, 26.0] (26.0, 29.0] (29.0, 30.0] (5.999, 26.0]
# CDRGLOB SEX
# 0       1      591.280556   625.282840   631.573783           NaN
#         2      522.602615   564.444475   574.193211    615.863000
# 1       1      584.962800   604.897027   631.686080    592.954023
#         2      525.461836   544.237409   531.811682    518.913937
# 2       1      593.739824   639.744400          NaN    598.317187
#         2      498.445600   514.568250          NaN    522.425921
# 3       1             NaN          NaN          NaN    550.814857
#         2      468.140000          NaN          NaN    484.156000
#
# INDEPEND                                          3                            \
# NACCMMSE    (26.0, 29.0] (29.0, 30.0] (5.999, 26.0] (26.0, 29.0] (29.0, 30.0]
# CDRGLOB SEX
# 0       1     529.726000          NaN           NaN          NaN          NaN
# ...
